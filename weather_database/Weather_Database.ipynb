# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# Import the API key.
from config import g_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16800\944702831.py in <module>
#       6
#       7 # Import the API key.
# ----> 8 from config import g_key
#
# ModuleNotFoundError: No module named 'config'

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low= -90.000, high= 90.000, size=2000)
lngs = np.random.uniform(low= -180.000, high= 180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 740

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b05f7fd70b27a65f0aff26106c1f0dca'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE 
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_desc = city_weather['weather'][0]['description']
        
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Current Description": city_weather_desc,
                         "Humidity": city_humidity,
                         "Clouldiness" : city_cloud,
                         "Wind Speed": city_wind,
                         "Country": city_country
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | shagonar
# Processing Record 2 of Set 1 | boyabat
# Processing Record 3 of Set 1 | tabou
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | kaitangata
# Processing Record 6 of Set 1 | ust-nera
# Processing Record 7 of Set 1 | prince rupert
# Processing Record 8 of Set 1 | bereznik
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | constitucion
# Processing Record 11 of Set 1 | umm jarr
# City not found. Skipping...
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | college
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | tooele
# Processing Record 17 of Set 1 | kracheh
# City not found. Skipping...
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | guerrero negro
# Processing Record 23 of Set 1 | te anau
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | pakenham
# Processing Record 27 of Set 1 | aksaray
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | mogadishu
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | grindavik
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | broome
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | vestmannaeyjar
# Processing Record 43 of Set 1 | calama
# Processing Record 44 of Set 1 | san patricio
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | pontianak
# Processing Record 47 of Set 1 | san mateo del mar
# Processing Record 48 of Set 1 | kavaratti
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | churapcha
# Processing Record 1 of Set 2 | tiznit
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | atambua
# Processing Record 4 of Set 2 | porto novo
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | zhangye
# Processing Record 7 of Set 2 | bolu
# Processing Record 8 of Set 2 | torbay
# Processing Record 9 of Set 2 | toamasina
# Processing Record 10 of Set 2 | krasnoselkup
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | marsa matruh
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | noumea
# Processing Record 15 of Set 2 | san quintin
# Processing Record 16 of Set 2 | santa elena
# Processing Record 17 of Set 2 | nome
# Processing Record 18 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | villa del rosario
# Processing Record 22 of Set 2 | snasa
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | saint-augustin
# Processing Record 25 of Set 2 | bogovarovo
# Processing Record 26 of Set 2 | alghero
# Processing Record 27 of Set 2 | husavik
# Processing Record 28 of Set 2 | tutoia
# Processing Record 29 of Set 2 | dhidhdhoo
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | upata
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | hamilton
# Processing Record 36 of Set 2 | lubyany
# Processing Record 37 of Set 2 | tunduru
# City not found. Skipping...
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | boma
# Processing Record 40 of Set 2 | havre-saint-pierre
# Processing Record 41 of Set 2 | olinda
# Processing Record 42 of Set 2 | antofagasta
# Processing Record 43 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 2 | faya
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | russellville
# Processing Record 48 of Set 2 | nishihara
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | yar-sale
# Processing Record 2 of Set 3 | kyren
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | sault sainte marie
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | matagami
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | jian
# Processing Record 10 of Set 3 | onega
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | naze
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | shimoda
# Processing Record 16 of Set 3 | jalu
# Processing Record 17 of Set 3 | riberalta
# Processing Record 18 of Set 3 | dharchula
# Processing Record 19 of Set 3 | muncar
# Processing Record 20 of Set 3 | port shepstone
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | bluff
# Processing Record 23 of Set 3 | praya
# Processing Record 24 of Set 3 | berberati
# Processing Record 25 of Set 3 | yarim
# Processing Record 26 of Set 3 | beitbridge
# Processing Record 27 of Set 3 | kapaa
# Processing Record 28 of Set 3 | matara
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | palaikastron
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | provideniya
# Processing Record 35 of Set 3 | anadyr
# Processing Record 36 of Set 3 | tansen
# Processing Record 37 of Set 3 | inhambane
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | novobirilyussy
# Processing Record 40 of Set 3 | kawalu
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | chicama
# Processing Record 43 of Set 3 | martapura
# Processing Record 44 of Set 3 | klaksvik
# Processing Record 45 of Set 3 | santa rosalia
# Processing Record 46 of Set 3 | clyde river
# Processing Record 47 of Set 3 | corinto
# Processing Record 48 of Set 3 | karratha
# Processing Record 49 of Set 3 | yerbogachen
# Processing Record 50 of Set 3 | poronaysk
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | chokwe
# Processing Record 3 of Set 4 | shingu
# Processing Record 4 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 4 | chuy
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | port lincoln
# Processing Record 8 of Set 4 | manoharpur
# Processing Record 9 of Set 4 | katsuura
# Processing Record 10 of Set 4 | okhotsk
# Processing Record 11 of Set 4 | nioki
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | hailin
# Processing Record 14 of Set 4 | cayenne
# Processing Record 15 of Set 4 | palmer
# Processing Record 16 of Set 4 | yellowknife
# Processing Record 17 of Set 4 | new norfolk
# Processing Record 18 of Set 4 | mehamn
# Processing Record 19 of Set 4 | praia da vitoria
# Processing Record 20 of Set 4 | uelzen
# Processing Record 21 of Set 4 | kita
# Processing Record 22 of Set 4 | banjar
# Processing Record 23 of Set 4 | holme
# Processing Record 24 of Set 4 | mentok
# City not found. Skipping...
# Processing Record 25 of Set 4 | didwana
# Processing Record 26 of Set 4 | lavrentiya
# Processing Record 27 of Set 4 | namibe
# Processing Record 28 of Set 4 | doha
# Processing Record 29 of Set 4 | javanrud
# Processing Record 30 of Set 4 | hithadhoo
# Processing Record 31 of Set 4 | batagay-alyta
# Processing Record 32 of Set 4 | khani
# Processing Record 33 of Set 4 | chapais
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | teknaf
# Processing Record 36 of Set 4 | muros
# Processing Record 37 of Set 4 | tumen
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | yulara
# Processing Record 40 of Set 4 | waipawa
# Processing Record 41 of Set 4 | bandar
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | olafsvik
# Processing Record 44 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 4 | strezhevoy
# Processing Record 46 of Set 4 | henties bay
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | taybad
# Processing Record 49 of Set 4 | ostrovnoy
# Processing Record 50 of Set 4 | bengkulu
# Processing Record 1 of Set 5 | mairinque
# Processing Record 2 of Set 5 | saint-louis
# Processing Record 3 of Set 5 | bilibino
# Processing Record 4 of Set 5 | russell
# Processing Record 5 of Set 5 | riyadh
# Processing Record 6 of Set 5 | bonthe
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | stara vyzhivka
# Processing Record 9 of Set 5 | glogow
# Processing Record 10 of Set 5 | cururupu
# Processing Record 11 of Set 5 | marivan
# Processing Record 12 of Set 5 | kilindoni
# Processing Record 13 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 5 | ahrensburg
# Processing Record 15 of Set 5 | meulaboh
# Processing Record 16 of Set 5 | katherine
# Processing Record 17 of Set 5 | najran
# Processing Record 18 of Set 5 | venado tuerto
# Processing Record 19 of Set 5 | shamkhal
# Processing Record 20 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 5 | saint george
# Processing Record 22 of Set 5 | rivadavia
# Processing Record 23 of Set 5 | vila franca do campo
# Processing Record 24 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 5 | puerto carreno
# Processing Record 26 of Set 5 | nabire
# Processing Record 27 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 5 | sawtell
# Processing Record 29 of Set 5 | baghmara
# Processing Record 30 of Set 5 | turukhansk
# Processing Record 31 of Set 5 | east london
# Processing Record 32 of Set 5 | osypenko
# Processing Record 33 of Set 5 | nowy dwor gdanski
# Processing Record 34 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 5 | flinders
# Processing Record 36 of Set 5 | ancud
# Processing Record 37 of Set 5 | woodward
# Processing Record 38 of Set 5 | trairi
# Processing Record 39 of Set 5 | fairbanks
# Processing Record 40 of Set 5 | poum
# Processing Record 41 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | storforshei
# Processing Record 44 of Set 5 | darhan
# Processing Record 45 of Set 5 | daru
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | faanui
# Processing Record 48 of Set 5 | safford
# Processing Record 49 of Set 5 | norman wells
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | torello
# Processing Record 2 of Set 6 | brenham
# Processing Record 3 of Set 6 | le port
# Processing Record 4 of Set 6 | tual
# Processing Record 5 of Set 6 | aklavik
# Processing Record 6 of Set 6 | san cristobal
# Processing Record 7 of Set 6 | pailon
# Processing Record 8 of Set 6 | salym
# Processing Record 9 of Set 6 | phrae
# Processing Record 10 of Set 6 | ormstown
# Processing Record 11 of Set 6 | bosaso
# Processing Record 12 of Set 6 | mananjary
# Processing Record 13 of Set 6 | riviere-au-renard
# Processing Record 14 of Set 6 | ribeira grande
# Processing Record 15 of Set 6 | dalvik
# Processing Record 16 of Set 6 | metro
# Processing Record 17 of Set 6 | vanimo
# Processing Record 18 of Set 6 | qaqortoq
# Processing Record 19 of Set 6 | vostok
# Processing Record 20 of Set 6 | bathsheba
# Processing Record 21 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 6 | mosina
# Processing Record 23 of Set 6 | lisakovsk
# Processing Record 24 of Set 6 | moerai
# Processing Record 25 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 26 of Set 6 | chengde
# Processing Record 27 of Set 6 | evensk
# Processing Record 28 of Set 6 | la reforma
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | tautira
# Processing Record 31 of Set 6 | bowen
# Processing Record 32 of Set 6 | ixtapa
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | aquiraz
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | luntal
# Processing Record 37 of Set 6 | varhaug
# Processing Record 38 of Set 6 | hay river
# Processing Record 39 of Set 6 | issia
# Processing Record 40 of Set 6 | padang
# Processing Record 41 of Set 6 | sao filipe
# Processing Record 42 of Set 6 | dongsheng
# Processing Record 43 of Set 6 | margate
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | mayumba
# Processing Record 46 of Set 6 | at-bashi
# Processing Record 47 of Set 6 | trige
# Processing Record 48 of Set 6 | pucallpa
# Processing Record 49 of Set 6 | ilhabela
# Processing Record 50 of Set 6 | vostochnyy
# Processing Record 1 of Set 7 | mendi
# Processing Record 2 of Set 7 | omboue
# Processing Record 3 of Set 7 | kamenka
# Processing Record 4 of Set 7 | charters towers
# Processing Record 5 of Set 7 | nanortalik
# Processing Record 6 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 7 | killam
# Processing Record 8 of Set 7 | malartic
# Processing Record 9 of Set 7 | san lawrenz
# Processing Record 10 of Set 7 | barabai
# Processing Record 11 of Set 7 | port victoria
# Processing Record 12 of Set 7 | pustoshka
# Processing Record 13 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 14 of Set 7 | ylojarvi
# Processing Record 15 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 7 | belton
# Processing Record 17 of Set 7 | rayadrug
# Processing Record 18 of Set 7 | kijang
# Processing Record 19 of Set 7 | bambous virieux
# Processing Record 20 of Set 7 | merritt
# Processing Record 21 of Set 7 | ducheng
# Processing Record 22 of Set 7 | segezha
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | westport
# Processing Record 25 of Set 7 | robertsport
# Processing Record 26 of Set 7 | mgandu
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | deputatskiy
# Processing Record 29 of Set 7 | shu
# Processing Record 30 of Set 7 | aras
# Processing Record 31 of Set 7 | calvinia
# Processing Record 32 of Set 7 | puri
# Processing Record 33 of Set 7 | lepe
# Processing Record 34 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 7 | nizhniy kuranakh
# Processing Record 36 of Set 7 | taoudenni
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | lamu
# Processing Record 39 of Set 7 | ovalle
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | atar
# Processing Record 42 of Set 7 | mountain home
# Processing Record 43 of Set 7 | tres barras
# Processing Record 44 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 7 | surt
# Processing Record 46 of Set 7 | naryan-mar
# Processing Record 47 of Set 7 | pangkalanbuun
# Processing Record 48 of Set 7 | teya
# Processing Record 49 of Set 7 | evanston
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | aldan
# Processing Record 2 of Set 8 | esso
# Processing Record 3 of Set 8 | kahului
# Processing Record 4 of Set 8 | sao joao da barra
# Processing Record 5 of Set 8 | ouro preto do oeste
# Processing Record 6 of Set 8 | unecha
# Processing Record 7 of Set 8 | vao
# Processing Record 8 of Set 8 | arteaga
# Processing Record 9 of Set 8 | aswan
# Processing Record 10 of Set 8 | beloha
# Processing Record 11 of Set 8 | saquarema
# Processing Record 12 of Set 8 | haines junction
# Processing Record 13 of Set 8 | tairua
# Processing Record 14 of Set 8 | zhigansk
# Processing Record 15 of Set 8 | sobolevo
# Processing Record 16 of Set 8 | buchanan
# Processing Record 17 of Set 8 | murgab
# Processing Record 18 of Set 8 | dikson
# Processing Record 19 of Set 8 | plateros
# Processing Record 20 of Set 8 | broken hill
# Processing Record 21 of Set 8 | sola
# Processing Record 22 of Set 8 | rawatsar
# Processing Record 23 of Set 8 | moose factory
# Processing Record 24 of Set 8 | arcos
# Processing Record 25 of Set 8 | vagur
# Processing Record 26 of Set 8 | camana
# Processing Record 27 of Set 8 | ahipara
# Processing Record 28 of Set 8 | tasiilaq
# Processing Record 29 of Set 8 | kazanka
# Processing Record 30 of Set 8 | pavlogradka
# Processing Record 31 of Set 8 | pangnirtung
# Processing Record 32 of Set 8 | tornio
# Processing Record 33 of Set 8 | polunochnoye
# Processing Record 34 of Set 8 | tashtyp
# Processing Record 35 of Set 8 | portland
# Processing Record 36 of Set 8 | bismarck
# Processing Record 37 of Set 8 | ponta do sol
# Processing Record 38 of Set 8 | lompoc
# Processing Record 39 of Set 8 | qiongshan
# Processing Record 40 of Set 8 | tarashcha
# Processing Record 41 of Set 8 | sorland
# Processing Record 42 of Set 8 | hrodna
# Processing Record 43 of Set 8 | banda aceh
# Processing Record 44 of Set 8 | goundi
# Processing Record 45 of Set 8 | alice springs
# Processing Record 46 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 8 | mercedes
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | tucupita
# Processing Record 50 of Set 8 | longyearbyen
# Processing Record 1 of Set 9 | tura
# Processing Record 2 of Set 9 | japura
# Processing Record 3 of Set 9 | boyolangu
# Processing Record 4 of Set 9 | cherskiy
# Processing Record 5 of Set 9 | bima
# Processing Record 6 of Set 9 | lasa
# Processing Record 7 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 8 of Set 9 | xacmaz
# Processing Record 9 of Set 9 | ruian
# City not found. Skipping...
# Processing Record 10 of Set 9 | huilong
# Processing Record 11 of Set 9 | oyama
# Processing Record 12 of Set 9 | awbari
# Processing Record 13 of Set 9 | eston
# Processing Record 14 of Set 9 | rio grande
# Processing Record 15 of Set 9 | saskylakh
# Processing Record 16 of Set 9 | isangel
# Processing Record 17 of Set 9 | kerema
# Processing Record 18 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 9 | bac lieu
# Processing Record 20 of Set 9 | kuching
# Processing Record 21 of Set 9 | itoman
# Processing Record 22 of Set 9 | ust-kulom
# Processing Record 23 of Set 9 | mecca
# Processing Record 24 of Set 9 | ovsyanka
# Processing Record 25 of Set 9 | tatsuno
# Processing Record 26 of Set 9 | ihtiman
# Processing Record 27 of Set 9 | horsham
# Processing Record 28 of Set 9 | marzuq
# Processing Record 29 of Set 9 | hami
# Processing Record 30 of Set 9 | kokopo
# Processing Record 31 of Set 9 | saint-joseph
# Processing Record 32 of Set 9 | atherton
# Processing Record 33 of Set 9 | dingle
# Processing Record 34 of Set 9 | san matias
# Processing Record 35 of Set 9 | cidreira
# Processing Record 36 of Set 9 | ambon
# Processing Record 37 of Set 9 | los llanos de aridane
# Processing Record 38 of Set 9 | portobelo
# Processing Record 39 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 40 of Set 9 | barth
# Processing Record 41 of Set 9 | nueva loja
# Processing Record 42 of Set 9 | khed
# Processing Record 43 of Set 9 | pochutla
# Processing Record 44 of Set 9 | usogorsk
# Processing Record 45 of Set 9 | vetluga
# Processing Record 46 of Set 9 | nemuro
# Processing Record 47 of Set 9 | karabulak
# Processing Record 48 of Set 9 | kurush
# Processing Record 49 of Set 9 | altoona
# Processing Record 50 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 1 of Set 10 | parkent
# Processing Record 2 of Set 10 | carutapera
# Processing Record 3 of Set 10 | aksu
# Processing Record 4 of Set 10 | basqal
# Processing Record 5 of Set 10 | banikoara
# Processing Record 6 of Set 10 | port blair
# Processing Record 7 of Set 10 | wagar
# Processing Record 8 of Set 10 | tezu
# Processing Record 9 of Set 10 | ayan
# Processing Record 10 of Set 10 | balti
# Processing Record 11 of Set 10 | caetes
# Processing Record 12 of Set 10 | pangai
# Processing Record 13 of Set 10 | narsaq
# Processing Record 14 of Set 10 | chimore
# Processing Record 15 of Set 10 | pindiga
# Processing Record 16 of Set 10 | vanavara
# Processing Record 17 of Set 10 | port hardy
# Processing Record 18 of Set 10 | da nang
# Processing Record 19 of Set 10 | dolores hidalgo
# Processing Record 20 of Set 10 | phan thiet
# Processing Record 21 of Set 10 | stepantsevo
# Processing Record 22 of Set 10 | mahon
# Processing Record 23 of Set 10 | fortuna
# Processing Record 24 of Set 10 | terney
# Processing Record 25 of Set 10 | potsdam
# Processing Record 26 of Set 10 | labytnangi
# Processing Record 27 of Set 10 | acapulco
# Processing Record 28 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 29 of Set 10 | upington
# Processing Record 30 of Set 10 | karimganj
# Processing Record 31 of Set 10 | huarmey
# Processing Record 32 of Set 10 | calabozo
# Processing Record 33 of Set 10 | zaragoza
# Processing Record 34 of Set 10 | quebo
# Processing Record 35 of Set 10 | grand baie
# Processing Record 36 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 10 | manjo
# Processing Record 38 of Set 10 | cabedelo
# Processing Record 39 of Set 10 | arman
# Processing Record 40 of Set 10 | tyrma
# Processing Record 41 of Set 10 | glencoe
# Processing Record 42 of Set 10 | tigre
# Processing Record 43 of Set 10 | codrington
# Processing Record 44 of Set 10 | funadhoo
# Processing Record 45 of Set 10 | pa sang
# Processing Record 46 of Set 10 | senno
# Processing Record 47 of Set 10 | arys
# Processing Record 48 of Set 10 | mumford
# Processing Record 49 of Set 10 | pacific grove
# Processing Record 50 of Set 10 | acari
# Processing Record 1 of Set 11 | mezen
# Processing Record 2 of Set 11 | brae
# Processing Record 3 of Set 11 | labuhan
# Processing Record 4 of Set 11 | abha
# Processing Record 5 of Set 11 | havelock
# Processing Record 6 of Set 11 | northam
# Processing Record 7 of Set 11 | makarska
# Processing Record 8 of Set 11 | svobodnyy
# Processing Record 9 of Set 11 | sinnamary
# Processing Record 10 of Set 11 | havoysund
# Processing Record 11 of Set 11 | tessalit
# Processing Record 12 of Set 11 | meru
# Processing Record 13 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 11 | peniche
# Processing Record 15 of Set 11 | udachnyy
# Processing Record 16 of Set 11 | andra
# Processing Record 17 of Set 11 | cherkessk
# Processing Record 18 of Set 11 | bara
# Processing Record 19 of Set 11 | comodoro rivadavia
# Processing Record 20 of Set 11 | mahibadhoo
# Processing Record 21 of Set 11 | krutikha
# Processing Record 22 of Set 11 | lindenberg
# Processing Record 23 of Set 11 | vila do maio
# Processing Record 24 of Set 11 | ndjole
# Processing Record 25 of Set 11 | yinchuan
# Processing Record 26 of Set 11 | prince george
# Processing Record 27 of Set 11 | marsh harbour
# Processing Record 28 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 11 | avera
# Processing Record 30 of Set 11 | birao
# Processing Record 31 of Set 11 | batouri
# Processing Record 32 of Set 11 | hervey bay
# Processing Record 33 of Set 11 | sirjan
# Processing Record 34 of Set 11 | zaraza
# Processing Record 35 of Set 11 | mitsamiouli
# Processing Record 36 of Set 11 | paamiut
# Processing Record 37 of Set 11 | ciudad bolivar
# Processing Record 38 of Set 11 | manokwari
# Processing Record 39 of Set 11 | naqadeh
# Processing Record 40 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 11 | molde
# Processing Record 42 of Set 11 | mitu
# Processing Record 43 of Set 11 | abalak
# Processing Record 44 of Set 11 | volot
# Processing Record 45 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 11 | maceio
# Processing Record 47 of Set 11 | gongzhuling
# Processing Record 48 of Set 11 | bubaque
# Processing Record 49 of Set 11 | san antonio
# Processing Record 50 of Set 11 | jishou
# Processing Record 1 of Set 12 | namatanai
# Processing Record 2 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 3 of Set 12 | cockburn town
# Processing Record 4 of Set 12 | gat
# Processing Record 5 of Set 12 | buctzotz
# Processing Record 6 of Set 12 | manyana
# Processing Record 7 of Set 12 | florianopolis
# Processing Record 8 of Set 12 | paris
# Processing Record 9 of Set 12 | kloulklubed
# Processing Record 10 of Set 12 | kangaba
# Processing Record 11 of Set 12 | wajima
# Processing Record 12 of Set 12 | saint-francois
# Processing Record 13 of Set 12 | san ignacio
# Processing Record 14 of Set 12 | yatou
# Processing Record 15 of Set 12 | san lorenzo
# Processing Record 16 of Set 12 | koslan
# Processing Record 17 of Set 12 | puerto baquerizo moreno
# Processing Record 18 of Set 12 | pittsburg
# Processing Record 19 of Set 12 | arlit
# Processing Record 20 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 21 of Set 12 | koshurnikovo
# Processing Record 22 of Set 12 | ribeira brava
# Processing Record 23 of Set 12 | manzil kamil
# Processing Record 24 of Set 12 | kupang
# Processing Record 25 of Set 12 | dayong
# Processing Record 26 of Set 12 | roma
# Processing Record 27 of Set 12 | hualmay
# Processing Record 28 of Set 12 | wajir
# Processing Record 29 of Set 12 | chinsali
# Processing Record 30 of Set 12 | sampit
# Processing Record 31 of Set 12 | kandrian
# Processing Record 32 of Set 12 | athenry
# Processing Record 33 of Set 12 | iracoubo
# Processing Record 34 of Set 12 | peterhead
# Processing Record 35 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 36 of Set 12 | barnstaple
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | manicore
# Processing Record 39 of Set 12 | redlands
# Processing Record 40 of Set 12 | mormugao
# Processing Record 41 of Set 12 | epe
# Processing Record 42 of Set 12 | lafiagi
# Processing Record 43 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 45 of Set 12 | catuday
# Processing Record 46 of Set 12 | manta
# Processing Record 47 of Set 12 | alice town
# Processing Record 48 of Set 12 | korla
# Processing Record 49 of Set 12 | fort nelson
# Processing Record 50 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 1 of Set 13 | touros
# Processing Record 2 of Set 13 | kirgiz-miyaki
# Processing Record 3 of Set 13 | neiafu
# Processing Record 4 of Set 13 | ashland
# Processing Record 5 of Set 13 | play cu
# City not found. Skipping...
# Processing Record 6 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | sambava
# Processing Record 8 of Set 13 | ligayan
# Processing Record 9 of Set 13 | port hedland
# Processing Record 10 of Set 13 | tromso
# Processing Record 11 of Set 13 | moranbah
# Processing Record 12 of Set 13 | urucara
# Processing Record 13 of Set 13 | san francisco
# Processing Record 14 of Set 13 | maragogi
# Processing Record 15 of Set 13 | ajdabiya
# Processing Record 16 of Set 13 | sioux lookout
# Processing Record 17 of Set 13 | inirida
# Processing Record 18 of Set 13 | buraydah
# Processing Record 19 of Set 13 | togur
# Processing Record 20 of Set 13 | mildura
# Processing Record 21 of Set 13 | atocha
# Processing Record 22 of Set 13 | ostersund
# Processing Record 23 of Set 13 | ust-omchug
# Processing Record 24 of Set 13 | pirgos
# Processing Record 25 of Set 13 | emerald
# Processing Record 26 of Set 13 | xunchang
# Processing Record 27 of Set 13 | yuzhno-sukhokumsk
# Processing Record 28 of Set 13 | indianola
# Processing Record 29 of Set 13 | kagoro
# Processing Record 30 of Set 13 | thaton
# Processing Record 31 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 13 | kaeo
# Processing Record 33 of Set 13 | port-gentil
# Processing Record 34 of Set 13 | manbij
# Processing Record 35 of Set 13 | lamballe
# Processing Record 36 of Set 13 | wattegama
# Processing Record 37 of Set 13 | shache
# Processing Record 38 of Set 13 | kota kinabalu
# Processing Record 39 of Set 13 | rosbach
# Processing Record 40 of Set 13 | chunskiy
# Processing Record 41 of Set 13 | kalmunai
# Processing Record 42 of Set 13 | mazatlan
# Processing Record 43 of Set 13 | abong mbang
# Processing Record 44 of Set 13 | bartica
# Processing Record 45 of Set 13 | totness
# Processing Record 46 of Set 13 | smithers
# Processing Record 47 of Set 13 | harstad
# Processing Record 48 of Set 13 | bairiki
# Processing Record 49 of Set 13 | dolores
# Processing Record 50 of Set 13 | navoi
# Processing Record 1 of Set 14 | vysokaya gora
# Processing Record 2 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 14 | port moresby
# Processing Record 4 of Set 14 | nueva helvecia
# Processing Record 5 of Set 14 | mbeya
# Processing Record 6 of Set 14 | ringkobing
# Processing Record 7 of Set 14 | mahajanga
# Processing Record 8 of Set 14 | port augusta
# Processing Record 9 of Set 14 | maniitsoq
# Processing Record 10 of Set 14 | general pico
# Processing Record 11 of Set 14 | boshnyakovo
# Processing Record 12 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 13 of Set 14 | krasnoarmeysk
# Processing Record 14 of Set 14 | aksum
# Processing Record 15 of Set 14 | key largo
# Processing Record 16 of Set 14 | boca do acre
# Processing Record 17 of Set 14 | beyneu
# Processing Record 18 of Set 14 | taos
# Processing Record 19 of Set 14 | caravelas
# Processing Record 20 of Set 14 | tartki
# City not found. Skipping...
# Processing Record 21 of Set 14 | union
# Processing Record 22 of Set 14 | anzhero-sudzhensk
# Processing Record 23 of Set 14 | ojinaga
# Processing Record 24 of Set 14 | akyab
# Processing Record 25 of Set 14 | deep river
# Processing Record 26 of Set 14 | kajaani
# Processing Record 27 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 14 | kharitonovo
# Processing Record 29 of Set 14 | kingston
# Processing Record 30 of Set 14 | baghdad
# Processing Record 31 of Set 14 | nador
# Processing Record 32 of Set 14 | shaoxing
# Processing Record 33 of Set 14 | kez
# Processing Record 34 of Set 14 | osakarovka
# Processing Record 35 of Set 14 | antalaha
# Processing Record 36 of Set 14 | sungaipenuh
# Processing Record 37 of Set 14 | pacifica
# Processing Record 38 of Set 14 | grand gaube
# Processing Record 39 of Set 14 | campoverde
# Processing Record 40 of Set 14 | kuusamo
# Processing Record 41 of Set 14 | luderitz
# Processing Record 42 of Set 14 | champerico
# Processing Record 43 of Set 14 | pemangkat
# Processing Record 44 of Set 14 | juegang
# Processing Record 45 of Set 14 | turinsk
# Processing Record 46 of Set 14 | campbellton
# Processing Record 47 of Set 14 | raudeberg
# Processing Record 48 of Set 14 | takoradi
# Processing Record 49 of Set 14 | burnie
# Processing Record 50 of Set 14 | kolaras
# Processing Record 1 of Set 15 | machali
# Processing Record 2 of Set 15 | auki
# Processing Record 3 of Set 15 | turbat
# Processing Record 4 of Set 15 | chumikan
# Processing Record 5 of Set 15 | las lomas
# Processing Record 6 of Set 15 | severnyy
# Processing Record 7 of Set 15 | inverell
# Processing Record 8 of Set 15 | weligama
# Processing Record 9 of Set 15 | doctor mora
# Processing Record 10 of Set 15 | destin
# Processing Record 11 of Set 15 | san juan nepomuceno
# Processing Record 12 of Set 15 | nerchinskiy zavod
# Processing Record 13 of Set 15 | sol-iletsk
# Processing Record 14 of Set 15 | ondo
# Processing Record 15 of Set 15 | zemio
# Processing Record 16 of Set 15 | tobol
# Processing Record 17 of Set 15 | vyborg
# Processing Record 18 of Set 15 | cap malheureux
# Processing Record 19 of Set 15 | kampene
# Processing Record 20 of Set 15 | bam
# Processing Record 21 of Set 15 | qasigiannguit
# Processing Record 22 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 15 | catamarca
# Processing Record 24 of Set 15 | samfya
# Processing Record 25 of Set 15 | batagay
# Processing Record 26 of Set 15 | keflavik
# Processing Record 27 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 15 | bayangol
# Processing Record 29 of Set 15 | rawson
# Processing Record 30 of Set 15 | baykit
# Processing Record 31 of Set 15 | yumen
# Processing Record 32 of Set 15 | alofi
# Processing Record 33 of Set 15 | jangaon
# Processing Record 34 of Set 15 | abu zabad
# Processing Record 35 of Set 15 | santa maria del oro
# Processing Record 36 of Set 15 | shestakovo
# Processing Record 37 of Set 15 | kichera
# Processing Record 38 of Set 15 | srednekolymsk
# Processing Record 39 of Set 15 | corsicana
# Processing Record 40 of Set 15 | dire
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 686

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp   Current Description  Humidity  \
# 0       Shagonar  51.5333   92.8000     19.65       overcast clouds        86
# 1        Boyabat  41.4689   34.7667     42.76            few clouds        70
# 2          Tabou   4.4230   -7.3528     76.69            few clouds        84
# 3       Souillac -20.5167   57.5167     73.40             clear sky        55
# 4     Kaitangata -46.2817  169.8464     57.49       overcast clouds        81
# 5       Ust-Nera  64.5667  143.2000     -8.41       overcast clouds        97
# 6  Prince Rupert  54.3161 -130.3201     40.71             clear sky        75
# 7       Bereznik  62.8551   42.7072     18.66         broken clouds        96
# 8        Rikitea -23.1203 -134.9692     73.76  heavy intensity rain        91
# 9   Constitucion -35.3333  -72.4167     56.66            few clouds        83
#
#    Clouldiness  Wind Speed Country
# 0           92        1.14      RU
# 1           14        1.45      TR
# 2           13        1.79      CI
# 3            0        3.85      MU
# 4           95        6.62      NZ
# 5          100        2.53      RU
# 6            1        7.96      CA
# 7           57        4.54      RU
# 8          100       22.32      PF
# 9           21       12.26      CL

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp   Current Description  Humidity  \
# 0       Shagonar  51.5333   92.8000     19.65       overcast clouds        86
# 1        Boyabat  41.4689   34.7667     42.76            few clouds        70
# 2          Tabou   4.4230   -7.3528     76.69            few clouds        84
# 3       Souillac -20.5167   57.5167     73.40             clear sky        55
# 4     Kaitangata -46.2817  169.8464     57.49       overcast clouds        81
# 5       Ust-Nera  64.5667  143.2000     -8.41       overcast clouds        97
# 6  Prince Rupert  54.3161 -130.3201     40.71             clear sky        75
# 7       Bereznik  62.8551   42.7072     18.66         broken clouds        96
# 8        Rikitea -23.1203 -134.9692     73.76  heavy intensity rain        91
# 9   Constitucion -35.3333  -72.4167     56.66            few clouds        83
#
#    Clouldiness  Wind Speed Country
# 0           92        1.14      RU
# 1           14        1.45      TR
# 2           13        1.79      CI
# 3            0        3.85      MU
# 4           95        6.62      NZ
# 5          100        2.53      RU
# 6            1        7.96      CA
# 7           57        4.54      RU
# 8          100       22.32      PF
# 9           21       12.26      CL

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Clouldiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
city_data_df = city_data_df[['City','Country','Lat','Lng','Max Temp','Humidity','Clouldiness','Wind Speed','Current Description']]


# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Shagonar      RU  51.5333   92.8000     19.65        86
# 1          Boyabat      TR  41.4689   34.7667     42.76        70
# 2            Tabou      CI   4.4230   -7.3528     76.69        84
# 3         Souillac      MU -20.5167   57.5167     73.40        55
# 4       Kaitangata      NZ -46.2817  169.8464     57.49        81
# ..             ...     ...      ...       ...       ...       ...
# 681     Shestakovo      RU  56.4915  103.9600     31.14        83
# 682        Kichera      RU  55.9375  110.0997     30.31        89
# 683  Srednekolymsk      RU  67.4500  153.6833     -4.56        99
# 684      Corsicana      US  32.0954  -96.4689     48.22        68
# 685           Dire      ML  12.2833  -10.9667     73.81        34
#
#      Clouldiness  Wind Speed Current Description
# 0             92        1.14     overcast clouds
# 1             14        1.45          few clouds
# 2             13        1.79          few clouds
# 3              0        3.85           clear sky
# 4             95        6.62     overcast clouds
# ..           ...         ...                 ...
# 681           92        9.53     overcast clouds
# 682           99        5.82     overcast clouds
# 683          100        6.26          light snow
# 684          100        4.61     overcast clouds
# 685          100        1.54     overcast clouds
#
# [686 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Clouldiness              int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
#city_data_df.to_csv(output_data_file, index_label = "City_ID")
city_data_df.to_csv(output_data_file, index_label = "City_ID")
